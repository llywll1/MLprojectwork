# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cols = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship',
        'race','sex','capital-gain','capital-loss','hours-per-week','native-country','Y']

# %%
df = pd.read_csv('./Data_income/all_data')
df
# Out:
#        Unnamed: 0  index  age          workclass    fnlwgt   education  \
# 0               0      0   39          State-gov   77516.0   Bachelors
# 1               1      1   50   Self-emp-not-inc   83311.0   Bachelors
# 2               2      2   38            Private  215646.0     HS-grad
# 3               3      3   53            Private  234721.0        11th
# 4               4      4   28            Private  338409.0   Bachelors
# ...           ...    ...  ...                ...       ...         ...
# 48837       48837  16277   39            Private  215419.0   Bachelors
# 48838       48838  16278   64                  ?  321403.0     HS-grad
# 48839       48839  16279   38            Private  374983.0   Bachelors
# 48840       48840  16280   44            Private   83891.0   Bachelors
# 48841       48841  16281   35       Self-emp-inc  182148.0   Bachelors
#
#        education-num       marital-status          occupation  \
# ...

# %%
del df['Unnamed: 0']
df
# Out:
#        index  age          workclass    fnlwgt   education  education-num  \
# 0          0   39          State-gov   77516.0   Bachelors           13.0
# 1          1   50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2          2   38            Private  215646.0     HS-grad            9.0
# 3          3   53            Private  234721.0        11th            7.0
# 4          4   28            Private  338409.0   Bachelors           13.0
# ...      ...  ...                ...       ...         ...            ...
# 48837  16277   39            Private  215419.0   Bachelors           13.0
# 48838  16278   64                  ?  321403.0     HS-grad            9.0
# 48839  16279   38            Private  374983.0   Bachelors           13.0
# 48840  16280   44            Private   83891.0   Bachelors           13.0
# 48841  16281   35       Self-emp-inc  182148.0   Bachelors           13.0
#
#             marital-status          occupation     relationship  \
# ...

# %%
del df['index']
df
# Out:
#        age          workclass    fnlwgt   education  education-num  \
# 0       39          State-gov   77516.0   Bachelors           13.0
# 1       50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2       38            Private  215646.0     HS-grad            9.0
# 3       53            Private  234721.0        11th            7.0
# 4       28            Private  338409.0   Bachelors           13.0
# ...    ...                ...       ...         ...            ...
# 48837   39            Private  215419.0   Bachelors           13.0
# 48838   64                  ?  321403.0     HS-grad            9.0
# 48839   38            Private  374983.0   Bachelors           13.0
# 48840   44            Private   83891.0   Bachelors           13.0
# 48841   35       Self-emp-inc  182148.0   Bachelors           13.0
#
#             marital-status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# ...

# %%
df['Y'] = df['Y'].apply(lambda x: x.split('.')[0])
df
# Out:
#        age          workclass    fnlwgt   education  education-num  \
# 0       39          State-gov   77516.0   Bachelors           13.0
# 1       50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2       38            Private  215646.0     HS-grad            9.0
# 3       53            Private  234721.0        11th            7.0
# 4       28            Private  338409.0   Bachelors           13.0
# ...    ...                ...       ...         ...            ...
# 48837   39            Private  215419.0   Bachelors           13.0
# 48838   64                  ?  321403.0     HS-grad            9.0
# 48839   38            Private  374983.0   Bachelors           13.0
# 48840   44            Private   83891.0   Bachelors           13.0
# 48841   35       Self-emp-inc  182148.0   Bachelors           13.0
#
#             marital-status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# ...

# %%
df1 = df.groupby("workclass")['Y'].value_counts(normalize=True).unstack()
df1 = df1.fillna(0)
df1 = df1.sort_values(' >50K')
df1
# Out:
# Y                     <=50K      >50K
# workclass
#  Never-worked      1.000000  0.000000
#  ?                 0.905323  0.094677
#  Without-pay       0.904762  0.095238
#  Private           0.782133  0.217867
#  State-gov         0.732458  0.267542
#  Self-emp-not-inc  0.721129  0.278871
#  Local-gov         0.704401  0.295599
#  Federal-gov       0.608240  0.391760
#  Self-emp-inc      0.446608  0.553392

# %%
lst1 = list(df1.index)
lst2 = list(range(1,(len(lst1)+1)))
di = dict(zip(lst1,lst2))
print(di)
# df1.plot(kind='bar', stacked='True')
# df1
# Out:
# {' Never-worked': 1, ' ?': 2, ' Without-pay': 3, ' Private': 4, ' State-gov': 5, ' Self-emp-not-inc': 6, ' Local-gov': 7, ' Federal-gov': 8, ' Self-emp-inc': 9}

# %%
df['workclass'].replace(di, inplace=True)
df
# Out:
#        age  workclass    fnlwgt   education  education-num  \
# 0       39          5   77516.0   Bachelors           13.0
# 1       50          6   83311.0   Bachelors           13.0
# 2       38          4  215646.0     HS-grad            9.0
# 3       53          4  234721.0        11th            7.0
# 4       28          4  338409.0   Bachelors           13.0
# ...    ...        ...       ...         ...            ...
# 48837   39          4  215419.0   Bachelors           13.0
# 48838   64          2  321403.0     HS-grad            9.0
# 48839   38          4  374983.0   Bachelors           13.0
# 48840   44          4   83891.0   Bachelors           13.0
# 48841   35          9  182148.0   Bachelors           13.0
#
#             marital-status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# 1       Married-civ-spouse     Exec-managerial          Husband
# ...

# %%
del df['education']

# %%
df
# Out:
#        age  workclass    fnlwgt  education-num       marital-status  \
# 0       39          5   77516.0           13.0        Never-married
# 1       50          6   83311.0           13.0   Married-civ-spouse
# 2       38          4  215646.0            9.0             Divorced
# 3       53          4  234721.0            7.0   Married-civ-spouse
# 4       28          4  338409.0           13.0   Married-civ-spouse
# ...    ...        ...       ...            ...                  ...
# 48837   39          4  215419.0           13.0             Divorced
# 48838   64          2  321403.0            9.0              Widowed
# 48839   38          4  374983.0           13.0   Married-civ-spouse
# 48840   44          4   83891.0           13.0             Divorced
# 48841   35          9  182148.0           13.0   Married-civ-spouse
#
#                occupation     relationship                 race      sex  \
# 0            Adm-clerical    Not-in-family                White     Male
# ...

# %%
df1 = df.groupby("occupation")['Y'].value_counts(normalize=True).unstack()
df1 = df1.sort_values(' >50K')
df1
df1.plot(kind='bar', stacked='True')
lst1 = list(df1.index)
print(lst1)
# Out:
# [' Priv-house-serv', ' Other-service', ' Handlers-cleaners', ' ?', ' Farming-fishing', ' Machine-op-inspct', ' Adm-clerical', ' Transport-moving', ' Craft-repair', ' Sales', ' Tech-support', ' Protective-serv', ' Armed-Forces', ' Prof-specialty', ' Exec-managerial']

# %%
lst2 = list(range(1,(len(lst1)+1)))
di = dict(zip(lst1,lst2))
print(di)
# Out:
# {' Priv-house-serv': 1, ' Other-service': 2, ' Handlers-cleaners': 3, ' ?': 4, ' Farming-fishing': 5, ' Machine-op-inspct': 6, ' Adm-clerical': 7, ' Transport-moving': 8, ' Craft-repair': 9, ' Sales': 10, ' Tech-support': 11, ' Protective-serv': 12, ' Armed-Forces': 13, ' Prof-specialty': 14, ' Exec-managerial': 15}

# %%
df['occupation'].replace(di, inplace=True)
df
# Out:
#        age  workclass    fnlwgt  education-num       marital-status  \
# 0       39          5   77516.0           13.0        Never-married
# 1       50          6   83311.0           13.0   Married-civ-spouse
# 2       38          4  215646.0            9.0             Divorced
# 3       53          4  234721.0            7.0   Married-civ-spouse
# 4       28          4  338409.0           13.0   Married-civ-spouse
# ...    ...        ...       ...            ...                  ...
# 48837   39          4  215419.0           13.0             Divorced
# 48838   64          2  321403.0            9.0              Widowed
# 48839   38          4  374983.0           13.0   Married-civ-spouse
# 48840   44          4   83891.0           13.0             Divorced
# 48841   35          9  182148.0           13.0   Married-civ-spouse
#
#        occupation     relationship                 race      sex  \
# 0               7    Not-in-family                White     Male
# ...

# %%
df1 = df

# %%
df11 = df1.groupby("race")['Y'].value_counts(normalize=True).unstack()
df11 = df11.sort_values(' >50K')
df11
df11.plot(kind='bar', stacked='True')

# %%
df11
# Out:
# Y                       <=50K      >50K
# race
#  Amer-Indian-Eskimo  0.882979  0.117021
#  Black               0.879189  0.120811
#  Other               0.876847  0.123153
#  White               0.746013  0.253987
#  Asian-Pac-Islander  0.730744  0.269256

# %%
lst1 = list(df11.index)
print(lst1)
lst2 = list(range(1,(len(lst1)+1)))
di = dict(zip(lst1,lst2))
print(di)
# Out:
# [' Amer-Indian-Eskimo', ' Black', ' Other', ' White', ' Asian-Pac-Islander']
# {' Amer-Indian-Eskimo': 1, ' Black': 2, ' Other': 3, ' White': 4, ' Asian-Pac-Islander': 5}

# %%
df1['race'].replace(di, inplace=True)
df1
# Out:
#        age  workclass    fnlwgt  education-num       marital-status  \
# 0       39          5   77516.0           13.0        Never-married
# 1       50          6   83311.0           13.0   Married-civ-spouse
# 2       38          4  215646.0            9.0             Divorced
# 3       53          4  234721.0            7.0   Married-civ-spouse
# 4       28          4  338409.0           13.0   Married-civ-spouse
# ...    ...        ...       ...            ...                  ...
# 48837   39          4  215419.0           13.0             Divorced
# 48838   64          2  321403.0            9.0              Widowed
# 48839   38          4  374983.0           13.0   Married-civ-spouse
# 48840   44          4   83891.0           13.0             Divorced
# 48841   35          9  182148.0           13.0   Married-civ-spouse
#
#        occupation     relationship  race      sex  capital-gain  capital-loss  \
# ...

# %%
di = dict({" Female": 0, " Male" : 1})
print(di)
# Out:
# {' Female': 0, ' Male': 1}

# %%
df1['sex'].replace(di, inplace=True)
df1
# Out:
#        age  workclass    fnlwgt  education-num       marital-status  \
# 0       39          5   77516.0           13.0        Never-married
# 1       50          6   83311.0           13.0   Married-civ-spouse
# 2       38          4  215646.0            9.0             Divorced
# 3       53          4  234721.0            7.0   Married-civ-spouse
# 4       28          4  338409.0           13.0   Married-civ-spouse
# ...    ...        ...       ...            ...                  ...
# 48837   39          4  215419.0           13.0             Divorced
# 48838   64          2  321403.0            9.0              Widowed
# 48839   38          4  374983.0           13.0   Married-civ-spouse
# 48840   44          4   83891.0           13.0             Divorced
# 48841   35          9  182148.0           13.0   Married-civ-spouse
#
#        occupation     relationship  race  sex  capital-gain  capital-loss  \
# 0               7    Not-in-family     4    1        2174.0           0.0
# ...

# %%
df11 = df1.groupby("native-country")['Y'].value_counts(normalize=True).unstack()
df11 = df11.sort_values(' >50K')
df11
df11.plot(kind='bar', stacked='True')

# %%
df11 = df11.fillna(0)

# %%
df11 = df11.sort_values(' >50K')
df11
# Out:
# Y                               <=50K      >50K
# native-country
#  Holand-Netherlands          1.000000  0.000000
#  Guatemala                   0.965909  0.034091
#  Outlying-US(Guam-USVI-etc)  0.956522  0.043478
#  Columbia                    0.952941  0.047059
#  Dominican-Republic          0.951456  0.048544
#  Mexico                      0.950578  0.049422
#  Nicaragua                   0.938776  0.061224
#  El-Salvador                 0.929032  0.070968
#  Trinadad&Tobago             0.925926  0.074074
#  Vietnam                     0.918605  0.081395
#  Laos                        0.913043  0.086957
#  Peru                        0.913043  0.086957
#  Honduras                    0.900000  0.100000
#  Puerto-Rico                 0.891304  0.108696
#  Haiti                       0.880000  0.120000
#  Ecuador                     0.866667  0.133333
#  Jamaica                     0.858491  0.141509
#  Scotland                    0.857143  0.142857
# ...

# %%
lst1 = list(df11.index)
lst2 = list(range(1,(len(lst1)+1)))
di = dict(zip(lst1,lst2))
print(di)
# Out:
# {' Holand-Netherlands': 1, ' Guatemala': 2, ' Outlying-US(Guam-USVI-etc)': 3, ' Columbia': 4, ' Dominican-Republic': 5, ' Mexico': 6, ' Nicaragua': 7, ' El-Salvador': 8, ' Trinadad&Tobago': 9, ' Vietnam': 10, ' Laos': 11, ' Peru': 12, ' Honduras': 13, ' Puerto-Rico': 14, ' Haiti': 15, ' Ecuador': 16, ' Jamaica': 17, ' Scotland': 18, ' Thailand': 19, ' South': 20, ' Portugal': 21, ' Poland': 22, ' United-States': 23, ' Cuba': 24, ' ?': 25, ' Hong': 26, ' Germany': 27, ' Philippines': 28, ' China': 29, ' Ireland': 30, ' Hungary': 31, ' Cambodia': 32, ' Italy': 33, ' Canada': 34, ' Japan': 35, ' Yugoslavia': 36, ' Greece': 37, ' England': 38, ' Iran': 39, ' Taiwan': 40, ' India': 41, ' France': 42}

# %%
df1['native-country'].replace(di, inplace=True)
df1
# Out:
#        age  workclass    fnlwgt  education-num       marital-status  \
# 0       39          5   77516.0           13.0        Never-married
# 1       50          6   83311.0           13.0   Married-civ-spouse
# 2       38          4  215646.0            9.0             Divorced
# 3       53          4  234721.0            7.0   Married-civ-spouse
# 4       28          4  338409.0           13.0   Married-civ-spouse
# ...    ...        ...       ...            ...                  ...
# 48837   39          4  215419.0           13.0             Divorced
# 48838   64          2  321403.0            9.0              Widowed
# 48839   38          4  374983.0           13.0   Married-civ-spouse
# 48840   44          4   83891.0           13.0             Divorced
# 48841   35          9  182148.0           13.0   Married-civ-spouse
#
#        occupation     relationship  race  sex  capital-gain  capital-loss  \
# 0               7    Not-in-family     4    1        2174.0           0.0
# ...

# %%
di = ({' <=50K': 0,' >50K': 1 })
print(di)
# Out:
# {' <=50K': 0, ' >50K': 1}

# %%
df1['Y'].replace(di, inplace=True)
df1
# Out:
#        age  workclass    fnlwgt  education-num       marital-status  \
# 0       39          5   77516.0           13.0        Never-married
# 1       50          6   83311.0           13.0   Married-civ-spouse
# 2       38          4  215646.0            9.0             Divorced
# 3       53          4  234721.0            7.0   Married-civ-spouse
# 4       28          4  338409.0           13.0   Married-civ-spouse
# ...    ...        ...       ...            ...                  ...
# 48837   39          4  215419.0           13.0             Divorced
# 48838   64          2  321403.0            9.0              Widowed
# 48839   38          4  374983.0           13.0   Married-civ-spouse
# 48840   44          4   83891.0           13.0             Divorced
# 48841   35          9  182148.0           13.0   Married-civ-spouse
#
#        occupation     relationship  race  sex  capital-gain  capital-loss  \
# 0               7    Not-in-family     4    1        2174.0           0.0
# ...

# %%
df2 = df1
df2
# Out:
#        age  workclass    fnlwgt  education-num       marital-status  \
# 0       39          5   77516.0           13.0        Never-married
# 1       50          6   83311.0           13.0   Married-civ-spouse
# 2       38          4  215646.0            9.0             Divorced
# 3       53          4  234721.0            7.0   Married-civ-spouse
# 4       28          4  338409.0           13.0   Married-civ-spouse
# ...    ...        ...       ...            ...                  ...
# 48837   39          4  215419.0           13.0             Divorced
# 48838   64          2  321403.0            9.0              Widowed
# 48839   38          4  374983.0           13.0   Married-civ-spouse
# 48840   44          4   83891.0           13.0             Divorced
# 48841   35          9  182148.0           13.0   Married-civ-spouse
#
#        occupation     relationship  race  sex  capital-gain  capital-loss  \
# 0               7    Not-in-family     4    1        2174.0           0.0
# ...

# %%
a = [1,2,3]
b = a
b.append(1)
a
# Out:
# [1, 2, 3, 1]

# %%
a = pd.get_dummies(df2['marital-status'], prefix='marital-status')
a
# Out:
#        marital-status_ Divorced  marital-status_ Married-AF-spouse  \
# 0                             0                                  0
# 1                             0                                  0
# 2                             1                                  0
# 3                             0                                  0
# 4                             0                                  0
# ...                         ...                                ...
# 48837                         1                                  0
# 48838                         0                                  0
# 48839                         0                                  0
# 48840                         1                                  0
# 48841                         0                                  0
#
#        marital-status_ Married-civ-spouse  \
# 0                                       0
# 1                                       1
# ...

# %%
df21 = pd.concat([df2,pd.get_dummies(df2['marital-status'], prefix='marital-status')],axis=1)
df21

# now drop the original 'country' column (you don't need it anymore)
df21.drop(['marital-status'],axis=1, inplace=True)
df21
# Out:
#        age  workclass    fnlwgt  education-num  occupation     relationship  \
# 0       39          5   77516.0           13.0           7    Not-in-family
# 1       50          6   83311.0           13.0          15          Husband
# 2       38          4  215646.0            9.0           3    Not-in-family
# 3       53          4  234721.0            7.0           3          Husband
# 4       28          4  338409.0           13.0          14             Wife
# ...    ...        ...       ...            ...         ...              ...
# 48837   39          4  215419.0           13.0          14    Not-in-family
# 48838   64          2  321403.0            9.0           4   Other-relative
# 48839   38          4  374983.0           13.0          14          Husband
# 48840   44          4   83891.0           13.0           7        Own-child
# 48841   35          9  182148.0           13.0          15          Husband
#
# ...

# %%
df22 = pd.concat([df21,pd.get_dummies(df21['relationship'], prefix='relationship')],axis=1)

# now drop the original 'country' column (you don't need it anymore)
df22.drop(['relationship'],axis=1, inplace=True)
df22
# Out:
#        age  workclass    fnlwgt  education-num  occupation  race  sex  \
# 0       39          5   77516.0           13.0           7     4    1
# 1       50          6   83311.0           13.0          15     4    1
# 2       38          4  215646.0            9.0           3     4    1
# 3       53          4  234721.0            7.0           3     2    1
# 4       28          4  338409.0           13.0          14     2    0
# ...    ...        ...       ...            ...         ...   ...  ...
# 48837   39          4  215419.0           13.0          14     4    0
# 48838   64          2  321403.0            9.0           4     2    1
# 48839   38          4  374983.0           13.0          14     4    1
# 48840   44          4   83891.0           13.0           7     5    1
# 48841   35          9  182148.0           13.0          15     4    1
#
#        capital-gain  capital-loss  hours-per-week  ...  \
# 0            2174.0           0.0            40.0  ...
# ...

# %%
note1 = df22.to_csv('./Data_income/clean_data')

# %%
df1 = pd.read_csv('./Data_income/clean_data',index_col=0)
df1
# Out:
#        age  workclass    fnlwgt  education-num  occupation  race  sex  \
# 0       39          5   77516.0           13.0           7     4    1
# 1       50          6   83311.0           13.0          15     4    1
# 2       38          4  215646.0            9.0           3     4    1
# 3       53          4  234721.0            7.0           3     2    1
# 4       28          4  338409.0           13.0          14     2    0
# ...    ...        ...       ...            ...         ...   ...  ...
# 48837   39          4  215419.0           13.0          14     4    0
# 48838   64          2  321403.0            9.0           4     2    1
# 48839   38          4  374983.0           13.0          14     4    1
# 48840   44          4   83891.0           13.0           7     5    1
# 48841   35          9  182148.0           13.0          15     4    1
#
#        capital-gain  capital-loss  hours-per-week  ...  \
# 0            2174.0           0.0            40.0  ...
# ...

# %%
df1 = df1.sort_values('Y')
df1
# Out:
#        age  workclass    fnlwgt  education-num  occupation  race  sex  \
# 0       39          5   77516.0           13.0           7     4    1
# 30374   42          5  121265.0           14.0          14     4    1
# 30376   45          4  297676.0           12.0          10     4    0
# 30377   52          4  114228.0            9.0           9     4    1
# 30378   22          7  121144.0           13.0          14     2    0
# ...    ...        ...       ...            ...         ...   ...  ...
# 8040    51          4  142717.0           16.0           9     4    0
# 8039    46          9  182655.0           11.0          15     4    1
# 8036    53          4  608184.0           13.0          15     2    1
# 8048    52          4  190909.0            9.0          15     4    1
# 48841   35          9  182148.0           13.0          15     4    1
#
#        capital-gain  capital-loss  hours-per-week  ...  \
# 0            2174.0           0.0            40.0  ...
# ...

# %%
df21 = df1[(df1['native-country']>15) & (df1['age']>24) & (df1['education-num']>10) & (df1["occupation"]>10) & (df1["sex"]==1) & (df1['hours-per-week']>40) & (df1['workclass']>3)]
df21
# Out:
#        age  workclass    fnlwgt  education-num  occupation  race  sex  \
# 30347   39          6  191342.0           13.0          15     5    1
# 30428   45          9  188330.0           13.0          15     4    1
# 30279   29          4  375482.0           13.0          14     4    1
# 30281   31          4  183000.0           15.0          11     4    1
# 30253   43          4  214781.0           14.0          15     4    1
# ...    ...        ...       ...            ...         ...   ...  ...
# 8047    62          4  153891.0           13.0          15     4    1
# 38303   62          6  215789.0           14.0          15     4    1
# 27213   44          4  131650.0           12.0          15     4    1
# 8039    46          9  182655.0           11.0          15     4    1
# 48841   35          9  182148.0           13.0          15     4    1
#
#        capital-gain  capital-loss  hours-per-week  ...  \
# 30347           0.0           0.0            50.0  ...
# ...

# %%
df21.groupby("Y").age.size()
# Out:
# Y
# 0     927
# 1    2300
# Name: age, dtype: int64
